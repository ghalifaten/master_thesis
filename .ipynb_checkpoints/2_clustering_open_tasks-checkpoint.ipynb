# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df_open_tasks = pd.read_csv("data/open_tasks_Corn_EKV.csv")

# %%
df_open_tasks.language.unique()
# Out:
# array(['DE', 'EN'], dtype=object)

# %%
df_en_tasks = df_open_tasks[df_open_tasks["language"] == "EN"]
df_en_tasks
# Out:
#                    documentId        tenant language  \
# 15287  4pXoyTaEFlJaVwAypNUXcg  Cornelsen EN       EN
# 15288   fq0rtjwXs79bZKorNNJxs  Cornelsen EN       EN
# 15975  5xeoxmBVXQg8cWOQAFn9RL  Cornelsen EN       EN
#
#                                         title  \
# 15287                              (API TEST)
# 15288                              (API_TEST)
# 15975  4 | 2.1 Picture description | bookcase
#
#                                              description context topic hints  \
# 15287  Was ist der Oberbegriff? Rande, Karotte, Lauch...     NaN   NaN    []
# 15288                   When was the battle of Waterloo?     NaN   NaN    []
# 15975                                                NaN     NaN   NaN    []
#
#                                  solutionSteps  replacements  resource  \
# 15287                               ['Gemüse']           NaN       NaN
# 15288  ['The battle of Waterloo was in 1815.']           NaN       NaN
# ...

# %%
df_de_tasks = df_open_tasks[df_open_tasks["language"] == "DE"]

# %%
sns.set_theme(style='white', 
              rc={'figure.figsize':(15,8)})

ax = sns.histplot(data=df_de_tasks,
                  x="word_count"
                 )
# ax.set_yscale("log")
title = plt.title("Distribution of GERMAN description text by length (in words).")
# Out:
# /home/faten/anaconda3/envs/tb_venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Remove empty descriptions
data = df_de_tasks[df_de_tasks["word_count"] > 0]["description"]

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/faten/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

german_stop_words = stopwords.words('german')

vectorizer = TfidfVectorizer(
    max_df=0.9,
    min_df=0.01,
    stop_words=german_stop_words,
)

X_tfidf = vectorizer.fit_transform(data)
print(f"n_samples: {X_tfidf.shape[0]}, n_features: {X_tfidf.shape[1]}")
# Out:
# n_samples: 130, n_features: 161

# %%
# Perform KMeans clustering for different number of clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_tfidf)
    wcss.append(kmeans.inertia_)

# Plot the elbow method graph
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()
# Out:
# /home/faten/anaconda3/envs/tb_venv/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

X_pca = PCA(n_components=2).fit_transform(X_tfidf.toarray())

# %%
from sklearn.cluster import KMeans
k = 3
kmeans = KMeans(
    n_clusters=k,
    max_iter=100,
    n_init=3,
    random_state=42,
).fit(X_tfidf)
cluster_ids, cluster_sizes = np.unique(kmeans.labels_, return_counts=True)
print(f"Number of elements assigned to each cluster: {cluster_sizes}")

# Plotting
plt.figure(figsize=(8, 6))
for cluster in range(k):
    plt.scatter(X_pca[kmeans.labels_ == cluster, 0], X_pca[kmeans.labels_ == cluster, 1], label=f'Cluster {cluster+1}')
plt.title('KMeans Clustering of Text Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# Number of elements assigned to each cluster: [108   8  14]
