# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df_open_tasks = pd.read_csv("data/open_tasks.csv")

# %%
df_en_tasks = df_open_tasks[df_open_tasks["language"] == "EN"]
df_en_tasks.head()
# Out:
#                 documentId language                       title  \
# 2   7TVZOkAoQvS71zub3YI9Uy       EN      The Battle of Waterloo
# 3   7x0pAQzpIEy794NCOxL9lg       EN     Demo Task Open Language
# 4   4M6yoJCBEbQ6zaztY5bG1U       EN  Chemistry: Neutralize Acid
# 5   2FVWlAlScuC9XzyS5SarpA       EN                   Example 1
# 14  8lxRyLzStOK9eUhNRal38O       EN       Task 01: Girl and Dog
#
#                                           description context  \
# 2      What do you know about the Battle of Waterloo?     NaN
# 3   Translate the sentence: Er ist der Präsident v...     NaN
# 4   Describe what you have to do in order to neutr...     NaN
# 5   Describe the interaction between the girl and ...     NaN
# 14  Describe the interaction between the girl and ...     NaN
#
#                                                 topic hints  \
# 2   {'id': 4598, 'name': 'English', 'description':...    []
# 3                                                 NaN    []
# ...

# %%
# data = df_en_tasks[df_en_tasks["word_count"] < 80]
# data = data["description"]
data = df_en_tasks["description"]
len(data)
# Out:
# 1198

# %%
sns.set_theme(style='white', 
              rc={'figure.figsize':(15,8)})

ax = sns.histplot(data=df_en_tasks,
                  x="word_count"
                 )
ax.set_yscale("log")
title = plt.title("Distribution of ENGLISH description text by length (in words).")
# Out:
# /home/faten/anaconda3/envs/tb_venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_df=0.5,
    min_df=5,
    stop_words="english",
)

X_tfidf = vectorizer.fit_transform(data)
print(f"n_samples: {X_tfidf.shape[0]}, n_features: {X_tfidf.shape[1]}")
# Out:
# n_samples: 1198, n_features: 318

# %%
# Perform KMeans clustering for different number of clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_tfidf)
    wcss.append(kmeans.inertia_)

# Plot the elbow method graph
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()
# Out:
# /home/faten/anaconda3/envs/tb_venv/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

X_pca = PCA(n_components=2).fit_transform(X_tfidf.toarray())

# %%
from sklearn.cluster import KMeans
k = 5
kmeans = KMeans(
    n_clusters=k,
    max_iter=100,
    n_init=3,
    random_state=42,
).fit(X_tfidf)
cluster_ids, cluster_sizes = np.unique(kmeans.labels_, return_counts=True)
print(f"Number of elements assigned to each cluster: {cluster_sizes}")

# Plotting
plt.figure(figsize=(8, 6))
for cluster in range(k):
    plt.scatter(X_pca[kmeans.labels_ == cluster, 0], X_pca[kmeans.labels_ == cluster, 1], label=f'Cluster {cluster+1}')
plt.title('KMeans Clustering of Text Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# Number of elements assigned to each cluster: [334 306 101 162 295]

# %%
from sklearn.cluster import KMeans
k = 3
kmeans = KMeans(
    n_clusters=k,
    max_iter=100,
    n_init=3,
    random_state=42,
).fit(X_tfidf)
cluster_ids, cluster_sizes = np.unique(kmeans.labels_, return_counts=True)
print(f"Number of elements assigned to each cluster: {cluster_sizes}")

# Plotting
plt.figure(figsize=(8, 6))
for cluster in range(k):
    plt.scatter(X_pca[kmeans.labels_ == cluster, 0], X_pca[kmeans.labels_ == cluster, 1], label=f'Cluster {cluster+1}')
plt.title('KMeans Clustering of Text Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
# Out:
# Number of elements assigned to each cluster: [336 162 700]
