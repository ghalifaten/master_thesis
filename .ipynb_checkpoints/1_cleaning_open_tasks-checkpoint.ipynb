# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import mysql.connector
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %%
cnx = mysql.connector.connect(user='root', password='taskbase',
                              host='127.0.0.1', port='3309', database='lernnavi')

# %%
query = "SELECT * FROM DocumentTypes"
df_types = pd.read_sql(query, cnx)
df_types.rename(columns={'id':'typeId', 'name':'type'}, inplace=True)
df_types.head()
# Out:
#    typeId                   type
# 0      26              BIT_MATCH
# 1      32       BIT_MATCH_MATRIX
# 2      27      BIT_MATCH_PICTURE
# 3      30    BIT_MULTIPLE_CHOICE
# 4      31  BIT_MULTIPLE_RESPONSE

# %%
query = "SELECT * FROM Documents"
df_tasks = pd.read_sql(query, cnx)
df_tasks = pd.merge(df_tasks, df_types, how="inner", on='typeId')
df_tasks.head()
# Out:
#    version          documentId           title  typeId    createdTime  \
# 0        8  Dyx07vCUuWqWSiHC6V                       3  1531728113426
# 1        9  Dyx07vCUuWqWSiHC6V   Aufgabe PT1.2       3  1531728228715
# 2       20  HurIW8u0XJAWSiN5aR                       3  1531729909418
# 3       21  HurIW8u0XJAWSiN5aR                       3  1531730025414
# 4       24  HurIW8u0XJAWSiN5aR  Aufgabe PT1.6a       3  1531730573408
#
#    authorId                                            content  \
# 0         2  {"id": "Dyx07vCUuWqWSiHC6V", "type": "HIGHLIGH...
# 1         2  {"id": "Dyx07vCUuWqWSiHC6V", "type": "HIGHLIGH...
# 2         2  {"id": "HurIW8u0XJAWSiN5aR", "type": "HIGHLIGH...
# 3         2  {"id": "HurIW8u0XJAWSiN5aR", "type": "HIGHLIGH...
# 4         2  {"id": "HurIW8u0XJAWSiN5aR", "type": "HIGHLIGH...
#
#              Status versionComment aiStatus feedbackComment customerId  \
# 0  WORK_IN_PROGRESS           None  INITIAL            None       None
# 1  WORK_IN_PROGRESS           None  INITIAL            None       None
# 2  WORK_IN_PROGRESS           None  INITIAL            None       None
# 3  WORK_IN_PROGRESS           None  INITIAL            None       None
# 4  WORK_IN_PROGRESS           None  INITIAL            None       None
#
#   language followUpTask       type
# 0     None         None  HIGHLIGHT
# 1     None         None  HIGHLIGHT
# 2     None         None  HIGHLIGHT
# 3     None         None  HIGHLIGHT
# 4     None         None  HIGHLIGHT

# %%
query = "SELECT * FROM LatestDocumentVersions"
df = pd.read_sql(query, cnx)
df_latest_task_versions = pd.merge(df_tasks, df, how="inner", on=["version", "documentId"])
df_latest_task_versions.head()
# Out:
#    version              documentId  \
# 0     2325        PT1-11a-restored
# 1     2388  7kQh-veLQfOanjx1QkhbKx
# 2     2395  d7SwsoVyAUP80fMioyhxzH
# 3     3786  4R58yTMxw8b5CK1F72eh0W
# 4     3788  2UiRhzBKL217r4pFiCA6Ek
#
#                                               title  typeId  createdTime_x  \
# 0                                   Aufgabe PT1.11a       3  1535643328825
# 1                                  Aufgabe PT 2.14a       3  1535660365797
# 2                                  Aufgabe PT 2.14c       3  1535661392063
# 3  Musteraufgabe D_Markieren_Adjektive_3.4_WORT_A_1       3  1562516756370
# 4         Ersatz 1.6b_Markieren mit mehreren Farben       3  1562516867617
#
#    authorId                                            content  \
# 0         2  {"id": "PT1-11a-restored", "type": "HIGHLIGHT"...
# 1         2  {"id": "7kQh-veLQfOanjx1QkhbKx", "type": "HIGH...
# 2         2  {"id": "d7SwsoVyAUP80fMioyhxzH", "type": "HIGH...
# 3        32  {"id": "4R58yTMxw8b5CK1F72eh0W", "type": "HIGH...
# 4        32  {"id": "2UiRhzBKL217r4pFiCA6Ek", "type": "HIGH...
#
#              Status versionComment aiStatus feedbackComment customerId  \
# 0  WORK_IN_PROGRESS           None  INITIAL            None       None
# 1  WORK_IN_PROGRESS           None  INITIAL            None       None
# 2  WORK_IN_PROGRESS           None  INITIAL            None       None
# 3  WORK_IN_PROGRESS           None  INITIAL            None       None
# 4  WORK_IN_PROGRESS           None  INITIAL            None       None
#
#   language followUpTask       type    id  createdTime_y
# 0     None         None  HIGHLIGHT  2693  1534434704301
# 1     None         None  HIGHLIGHT  1589  1532335779747
# 2     None         None  HIGHLIGHT  2516  1532336772750
# 3     None         None  HIGHLIGHT   927  1559076209311
# 4     None         None  HIGHLIGHT   425  1555145282057

# %%
columns_to_keep = ["documentId", "type", "title", "language"]
df = df_latest_task_versions[columns_to_keep]

# %%
df_content = df_latest_task_versions["content"].apply(json.loads).apply(pd.Series)
df_content.rename(columns={"id":"documentId"}, inplace=True)

# %%
df_open_tasks = df_content[df_content["type"] == "OPEN"].dropna(axis=1, how="all")
columns_to_keep = ["documentId", "tenant", "language", "title", "description", "context", "topic", "hints", "solutionSteps", "replacements", "resource", "sampleSolutions", "stepifier"]
df_open_tasks = df_open_tasks[columns_to_keep]
# df_open_tasks.head()

# %%
df_open_tasks.sample(5)
# Out:
#                    documentId  \
# 15902  92w4VLzj4nZ6CqRT67vRmm
# 14225   WBpXGmPRwzaCY4ClvaQEF
# 13948  1tdDuD0Jjfk8jo6541D1Sq
# 16947  2Ecwiu1esCx8uVGItEOmnS
# 16743  4fHzBC8AGaM6WS2QwbGMt3
#
#                                                   tenant language  \
# 15902          {'id': 17, 'name': 'connectsolutions_it'}      NaN
# 14225          {'id': 11, 'name': 'connectsolutions_de'}      NaN
# 13948                                                NaN      NaN
# 16947  {'id': 128, 'name': 'CV_641193ae7206291a2069a4...       DE
# 16743                 {'id': 139, 'name': 'EKV_English'}       EN
#
#                        title  \
# 15902  IT_M_CHM_Eval2_Q2_OLD
# 14225          DE_SVF_Exa_Q5
# 13948    Test Open Prompting
# 16947          PPmMv_L4_Ue03
# 16743    Work with the text.
#
#                                              description  \
# 15902  <table><tbody><tr><td>Cita un esempio di grupp...
# 14225  <p>Valérie, hingegen, ist sicher, dass eine Mu...
# 13948  <strong><font style="vertical-align: inherit;"...
# 16947  Schreibe den Satz im Passiv Präsens. <br>Der M...
# 16743   Look at the structure of the text We can do e...
#
#                                                  context  \
# 15902                                                NaN
# 14225                                                NaN
# 13948                                                NaN
# 16947
# 16743    We can do even better – by Lindsay Fern (21/...
#
#                                                    topic hints  \
# 15902  {'id': 5002, 'name': '9. Avviare misure contro...    []
# 14225  {'id': 3260, 'name': 'Prozessmanagement', 'des...    []
# 13948                                                NaN    []
# 16947                                                NaN    []
# 16743                                                NaN    []
#
#                                            solutionSteps replacements  \
# 15902  [<table><tbody><tr><td>Sono dei gruppi i cui i...          NaN
# 14225                                                 []          NaN
# 13948                                                 []          NaN
# 16947                                                 []          NaN
# 16743                                                 []          NaN
#
#       resource                                    sampleSolutions stepifier
# 15902      NaN                                                 []   KEYWORD
# 14225      NaN                                                 []   KEYWORD
# 13948      NaN                                                 []   KEYWORD
# 16947      NaN               ["Der Erfolg kann gefeiert werden."]  SENTENCE
# 16743      NaN  [" The author finishes her article with the st...  SENTENCE

# %%
df_open_tasks.dropna(subset=["tenant"], inplace=True)
len(df_open_tasks)
# Out:
# 3432

# %%
df_open_tasks["tenant"] = df_open_tasks["tenant"].apply(pd.Series)["name"]

# %%
df_open_tasks = df_open_tasks[df_open_tasks["tenant"].isin(["Cornelsen DE", "Cornelsen EN", "EKV_Physik"]) ]

# %% [markdown]
# **Cleaning description**

# %%
df_open_tasks["description"] = df_open_tasks["description"].apply(lambda str: BeautifulSoup(str, 'html.parser').get_text().strip())
df_open_tasks.head()
# Out:
#                    documentId        tenant language  \
# 14977  awg5HdhPj3M8BT32YCOHDF  Cornelsen EN       DE
# 14989  81xdUMIFiyC7gTSwml1MTv  Cornelsen DE       DE
# 14990  7fE9sk0x2amalma0takBp5  Cornelsen DE       DE
# 14991  7CUm7BcYBG79uI8VPMUKCo  Cornelsen DE       DE
# 15031  6eVh0sUk73laFRNimbk7MC  Cornelsen DE       DE
#
#                                                    title  \
# 14977  (API TEST, please ignore) 3.2 Gedicht | Inhalt...
# 14989          Archive | 4.1 Erlebnislyrik | Kennzeichen
# 14990   Archive | 3.3 Schlussteil Interpretationsaufsatz
# 14991        Archive | 3.2 Gedicht | Inhaltliche Aspekte
# 15031                             DaF | Relativpronomen
#
#                                              description context  \
# 14977                                                        NaN
# 14989  Was ist ein Kennzeichen der Erlebnislyrik? Ant...     NaN
# 14990  Welches Vorgehen planen Sie für den Schlusstei...     NaN
# 14991  Auf welchen inhaltlichen Aspekt hin würden Sie...     NaN
# 15031  Mache aus den zwei Sätzen einen Relativsatz.Ic...     NaN
#
#                                                    topic hints  \
# 14977                                                NaN    []
# 14989  {'id': 5350, 'name': 'Essay 3', 'description':...    []
# 14990  {'id': 5349, 'name': 'Essay 1', 'description':...    []
# 14991  {'id': 5349, 'name': 'Essay 1', 'description':...    []
# 15031  {'id': 5357, 'name': 'DaF', 'description': '',...    []
#
#                                            solutionSteps replacements  \
# 14977                                                 []          NaN
# 14989                                                 []          NaN
# 14990                                                 []          NaN
# 14991                                                 []          NaN
# 15031  [Ich arbeite gern mit dem Laptop, den ich letz...          NaN
#
#       resource sampleSolutions stepifier
# 14977      NaN              []  SENTENCE
# 14989      NaN              []   KEYWORD
# 14990      NaN              []   KEYWORD
# 14991      NaN              []   KEYWORD
# 15031      NaN              []   KEYWORD

# %% [markdown]
# **Fixing language field**

# %% [raw]
# !pip install langdetect

# %% [raw]
# from langdetect import detect

# %% [raw]
# existing_language = df_open_tasks.dropna(subset=["language"])
# missing_language = df_open_tasks[df_open_tasks['language'].isna()]

# %% [raw]
# len(df_open_tasks) == len(existing_language) + len(missing_language)

# %% [raw]
# def detect_lang(text):
#     try:
#         lang = detect(text)
#         return lang.upper()
#     except:
#         return ""
#
# missing_language["language"] = missing_language["description"].apply(lambda text: detect_lang(text))

# %% [raw]
# missing_language["language"].unique()

# %% [raw]
# L = len(missing_language)
# langs = ["DE", "EN", "FR", "IT"]
# l = len(missing_language[missing_language["language"].isin(langs)])
# print("Percentage of descriptions that were not correctly detected {:.2f}%".format((L - l) / L ))

# %% [raw]
# # Remove languages that are not DE, EN, FR or IT
# missing_language = missing_language[missing_language["language"].isin(langs)]
# df_open_tasks = pd.concat([existing_language, missing_language], ignore_index=True)

# %%
df_open_tasks["word_count"] = df_open_tasks["description"].apply(lambda s: len(s.split()))

# %%
df_open_tasks.to_csv("data/open_tasks_Corn_EKV.csv", index_label=False)
