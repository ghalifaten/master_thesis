# %% [markdown]
# Clustering the aspects, and looking at their distribution among the data instances.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from sklearn.decomposition import PCA
import nltk 
nltk.download('stopwords')
plt.rcParams["figure.figsize"] = (15,6)
# Out:
# [nltk_data] Downloading package stopwords to /home/faten/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Clustering

# %%
from scipy.spatial.distance import cdist

def get_tfidf(language, data):
    if language == "english":
        stop_words = stopwords.words('english')
    elif language == "german": 
        stop_words = stopwords.words('german')
    else: 
        raise language + " is not supported."

    # Vectorizer 
    vectorizer = TfidfVectorizer(
        max_df=0.9,
        min_df=0.01,
        stop_words=stop_words,
    )

    X_tfidf = vectorizer.fit_transform(data)
    print(f"n_samples: {X_tfidf.shape[0]}, n_features: {X_tfidf.shape[1]}")

    return X_tfidf


def plot_elbow(X_tfidf, title, language, save_plot=True):
    X_pca = PCA(n_components=2).fit_transform(X_tfidf.toarray())

    fig, ax = plt.subplots(1, 1)
    wcss = []
    distortions = []
    max=11
    for i in range(1, max):
        kmeans = KMeans(
            n_clusters=i, 
            init='k-means++', 
            random_state=42)
        kmeans.fit(X_pca)
        wcss.append(kmeans.inertia_) 
        
    ax.plot(range(1, max), wcss, marker='o', linestyle='--')    
    
    ax.title.set_text(title)
    ax.set_ylabel("WCSS")
    ax.set_xlabel("Number of Clusters")
    ax.grid(True)
    if save_plot:
        ax.get_figure().savefig("figures/clust_elbow_"+language, bbox_inches="tight") 

def cluster(X_tfidf, k, title, language, save_plot=True):
    X_pca = PCA(n_components=2).fit_transform(X_tfidf.toarray())
    
    kmeans= KMeans(
        n_clusters=k,
        max_iter=100,
        n_init=3,
        random_state=42,
    ).fit(X_pca) 

    cluster_ids, cluster_sizes = np.unique(kmeans.labels_, return_counts=True)
    print(f"Number of elements assigned to each cluster: {cluster_sizes}") 

    # Plotting
    fig, ax = plt.subplots(1, 1)
    for cluster in range(k):
        ax.scatter(X_pca[kmeans.labels_ == cluster, 0], X_pca[kmeans.labels_ == cluster, 1], label=f'Cluster {cluster+1}')
    ax.title.set_text(title)
    ax.set_xlabel('Principal Component 1')
    ax.set_ylabel('Principal Component 2')
    # plt.legend()
    plt.show()
    if save_plot:
        ax.get_figure().savefig("figures/clusters_"+language, bbox_inches="tight")

# %% [markdown]
# <hr>

# %%
df = pd.read_csv("data/aspects_DE.csv")
df.dropna(subset=["description"], inplace=True)
data = df["description"] 
X_tfidf = get_tfidf(language="german", data=data) 
plot_elbow(X_tfidf=X_tfidf, title="Elbow method on German aspects", language="DE", save_plot=False)
# Out:
# n_samples: 43614, n_features: 62

# %%
cluster(X_tfidf=X_tfidf, k=3, title="Clusters on German aspects", language="DE", save_plot=False)
# Out:
# Number of elements assigned to each cluster: [17694 12574 13346]

# %% [markdown]
# <hr>

# %%
df = pd.read_csv("data/aspects_EN.csv")
df.dropna(subset=["description"], inplace=True)
data = df["description"] 
X_tfidf = get_tfidf(language="english", data=data) 
plot_elbow(X_tfidf=X_tfidf, title="Elbow method on English aspects", language="EN", save_plot=False)
# Out:
# n_samples: 7324, n_features: 89

# %%
cluster(X_tfidf=X_tfidf, k=3, title="Clusters on English tasks", language="EN", save_plot=False)
# Out:
# Number of elements assigned to each cluster: [5352  675 1297]

# %% [markdown]
# <hr>

# %% [markdown]
# # Distribution

# %%
import seaborn as sns

# %% [markdown]
# ### German

# %%
df = pd.read_csv("data/aspects_DE.csv")
df.head()
# Out:
#                    taskId  aspectId                     name  \
# 0  6GiDAn1lXN77UqQybxaa1N      8063  contains too little/753
# 1  6GiDAn1lXN77UqQybxaa1N      8067         is contained/749
# 2  1N8fnGOxojM7uMBAfjldQO      8067         is contained/749
# 3  6GiDAn1lXN77UqQybxaa1N      8075     is not contained/750
# 4  2nrIbSGCnBTaitH65i7FqT      7656         is contained/796
#
#                                          description  categoryId  \
# 0  Bitte zähle noch weitere Möbel und Einrichtung...         NaN
# 1  Es wurden genügend Möbel und Einrichtungsgegen...         NaN
# 2  Es wurden genügend Möbel und Einrichtungsgegen...         NaN
# 3  Es wurden keine Möbel und Einrichtungsgegenstä...         NaN
# 4                       Der Satz beginnt mit "Nein".         NaN
#
#             type  groupId
# 0  MISCONCEPTION      NaN
# 1        CONCEPT      NaN
# 2        CONCEPT      NaN
# 3  MISCONCEPTION      NaN
# 4        CONCEPT      NaN

# %%
len(df["taskId"].unique()), len(df["aspectId"].unique())
# Out:
# (1067, 2792)

# %% [markdown]
# **How many aspects per task?**

# %%
freq_df = df[["taskId", "aspectId"]].groupby(by="taskId").count().reset_index().rename(columns={"aspectId":"aspects_count"})

# %%
sns.histplot(data=freq_df, x="aspects_count")
# Out:
# <Axes: xlabel='aspects_count', ylabel='Count'>

# %%
freq_df['aspects_count'].mean()
# Out:
# 41.11902530459231

# %%
freq_df['aspects_count'].median()
# Out:
# 49.0

# %% [markdown]
# **The most frequent aspects**

# %%
df.head()
# Out:
#                    taskId  aspectId                     name  \
# 0  6GiDAn1lXN77UqQybxaa1N      8063  contains too little/753
# 1  6GiDAn1lXN77UqQybxaa1N      8067         is contained/749
# 2  1N8fnGOxojM7uMBAfjldQO      8067         is contained/749
# 3  6GiDAn1lXN77UqQybxaa1N      8075     is not contained/750
# 4  2nrIbSGCnBTaitH65i7FqT      7656         is contained/796
#
#                                          description  categoryId  \
# 0  Bitte zähle noch weitere Möbel und Einrichtung...         NaN
# 1  Es wurden genügend Möbel und Einrichtungsgegen...         NaN
# 2  Es wurden genügend Möbel und Einrichtungsgegen...         NaN
# 3  Es wurden keine Möbel und Einrichtungsgegenstä...         NaN
# 4                       Der Satz beginnt mit "Nein".         NaN
#
#             type  groupId
# 0  MISCONCEPTION      NaN
# 1        CONCEPT      NaN
# 2        CONCEPT      NaN
# 3  MISCONCEPTION      NaN
# 4        CONCEPT      NaN

# %%
sns.histplot(data=df, x="aspectId")
# Out:
# <Axes: xlabel='aspectId', ylabel='Count'>

# %% [markdown]
# **Co-occurrence**

# %%
occ_df = df[["taskId", "aspectId"]].groupby(by="taskId")["aspectId"].apply(list).reset_index().rename(columns={"aspectId":"aspectIds"})
occ_df.head()
# Out:
#                    taskId                                          aspectIds
# 0  11TmPwiOxTraHRLHAisXsd  [81254, 223298, 81242, 92638, 92639, 92640, 10...
# 1  1293GBkjDYEaXvgdCO44iO                                     [71033, 71034]
# 2  13UI7608E2c6uSrPNzIeD8  [114630, 184384, 114567, 184389, 184394, 11454...
# 3  14z4iMHY2C59ksyPre5OWh  [6095, 6096, 6097, 6098, 6099, 6100, 6101, 624...
# 4  15lJTTd7ChCah9fCEQs7Sk  [1415, 1631, 1417, 1416, 1418, 1419, 1632, 161...

# %% [markdown]
# ### English

# %%
df = pd.read_csv("data/aspects_EN.csv")
df.head()
# Out:
#                    taskId  aspectId                      name  \
# 0  arpZLB27MYq9MWTotPuJAy      7891  contains too little/1223
# 1  arpZLB27MYq9MWTotPuJAy      7893      wrong statement/1221
# 2  arpZLB27MYq9MWTotPuJAy      7892    correct statement/1220
# 3   RfcCuYoNUe7RBgytJfh1F      7979  contains too little/1461
# 4   RfcCuYoNUe7RBgytJfh1F      7980    correct statement/1459
#
#                                          description  categoryId  \
# 0               You mentioned not enough statements.         NaN
# 1  This sentences doesn't refer to the impact sta...         NaN
# 2     You correctly identified the impact statement.         NaN
# 3  You mentioned the importance of giving praise....         NaN
# 4     Praise is the recognition for doing good work.         NaN
#
#             type  groupId
# 0  MISCONCEPTION      NaN
# 1  MISCONCEPTION      NaN
# 2        CONCEPT      NaN
# 3  MISCONCEPTION      NaN
# 4        CONCEPT      NaN

# %%
len(df["taskId"].unique()), len(df["aspectId"].unique())
# Out:
# (244, 1492)

# %% [markdown]
# **How many aspects per task?**

# %%
freq_df = df[["taskId", "aspectId"]].groupby(by="taskId").count().reset_index().rename(columns={"aspectId":"aspects_count"})

# %%
sns.histplot(data=freq_df, x="aspects_count")
# Out:
# <Axes: xlabel='aspects_count', ylabel='Count'>

# %%
freq_df['aspects_count'].mean()
# Out:
# 32.545081967213115

# %%
freq_df['aspects_count'].median()
# Out:
# 27.0

# %% [markdown]
# **The most frequent aspects**

# %%
df.head()
# Out:
#                    taskId  aspectId                      name  \
# 0  arpZLB27MYq9MWTotPuJAy      7891  contains too little/1223
# 1  arpZLB27MYq9MWTotPuJAy      7893      wrong statement/1221
# 2  arpZLB27MYq9MWTotPuJAy      7892    correct statement/1220
# 3   RfcCuYoNUe7RBgytJfh1F      7979  contains too little/1461
# 4   RfcCuYoNUe7RBgytJfh1F      7980    correct statement/1459
#
#                                          description  categoryId  \
# 0               You mentioned not enough statements.         NaN
# 1  This sentences doesn't refer to the impact sta...         NaN
# 2     You correctly identified the impact statement.         NaN
# 3  You mentioned the importance of giving praise....         NaN
# 4     Praise is the recognition for doing good work.         NaN
#
#             type  groupId
# 0  MISCONCEPTION      NaN
# 1  MISCONCEPTION      NaN
# 2        CONCEPT      NaN
# 3  MISCONCEPTION      NaN
# 4        CONCEPT      NaN

# %%
sns.histplot(data=df, x="aspectId")
# Out:
# <Axes: xlabel='aspectId', ylabel='Count'>

# %% [markdown]
# **Co-occurrence**

# %%
occ_df = df[["taskId", "aspectId"]].groupby(by="taskId")["aspectId"].apply(list).reset_index().rename(columns={"aspectId":"aspectIds"})
occ_df.head()
# Out:
#                    taskId                                          aspectIds
# 0  11TmPwiOxTraHRLHAisXsd  [81254, 223298, 81242, 92638, 92639, 92640, 10...
# 1  1293GBkjDYEaXvgdCO44iO                                     [71033, 71034]
# 2  13UI7608E2c6uSrPNzIeD8  [114630, 184384, 114567, 184389, 184394, 11454...
# 3  14z4iMHY2C59ksyPre5OWh  [6095, 6096, 6097, 6098, 6099, 6100, 6101, 624...
# 4  15lJTTd7ChCah9fCEQs7Sk  [1415, 1631, 1417, 1416, 1418, 1419, 1632, 161...
